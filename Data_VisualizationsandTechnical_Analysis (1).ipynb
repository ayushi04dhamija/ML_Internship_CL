# %%
import pandas as pd
import csv

# %%
path =("C:/Users/Ayushi/Desktop/Hi/week2.csv")

# %%
df =pd.read_csv(path,index_col='Date')

# %%
#closeprice = df.columns.str.strip('closeprice')

# %%
#df.columns = closeprice.astype(int)

# %%
df.loc[:,'Close Price'].plot()
